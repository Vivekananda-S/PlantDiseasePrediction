# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32

#RGB Color channel
CHANNEL = 3

#number of times we will train the data
EPOCHS = 100

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "PlantVillage",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 2152 files belonging to 3 classes.

# %%
class_names = dataset.class_names
class_names
# Out:
# ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
#dataset is stored all the images in batch wise each batch contain 32 so len will be 68 ==> 68*32 = 2152+
len(dataset)
# Out:
# 68

# %%
#to increase the area of plt
plt.figure(figsize=(15,15))

for image_batch, label_batch in dataset.take(1):
    
    #to display batch elements
    for i in range(32):
        
        #Dividing the plt to subplots here we want to display 32 to 8->rows and 4->cols ==> 32 subplots
        ax = plt.subplot(8,4,i+1)
        
        #to visualize the image
        #Here imshow() function expects 3d array(3d array size shape of image( 256px, 256px, 3rgb))
        #astype will convert the floating value to specified type here it is uint8
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        
        #plt title set by class of image using label_batch
        plt.title(class_names[label_batch[i]])
        
        #plt graph axis set to off
        plt.axis("off")

# %%
# Now we divide the data for sub purposes
# 80% ==> training
# 20% ==> 10%validation, 10%test
# for each epochs we do validation by using this 10% of data
# now after compeletion of all the epochs we will the remaing 10% of data to measure the accuracy of the model

# %%
train_size = 0.8
len(dataset)*train_size
# Out:
# 54.400000000000006

# %%
train_ds = dataset.take(54)
len(train_ds)
# Out:
# 54

# %%
test_ds = dataset.skip(54)
len(test_ds)
# Out:
# 14

# %%
val_size = 0.1
len(dataset)*val_size
# Out:
# 6.800000000000001

# %%
val_ds = test_ds.take(7)
len(val_ds)
# Out:
# 7

# %%
test_ds = test_ds.skip(7)
len(test_ds)
# Out:
# 7

# %%
#Now all the above operations must be incorporated into a function
def get_dataset_partition_tf(ds, train_split = 0.8, val_split = 0.1, test_split = 0.1, shuffle=True, shuffle_size=10000):
    
    ds_size = len(ds)
    
    if shuffle:
        ds.shuffle(shuffle_size, seed=12)
        
    train_size = int(train_split * ds_size)
    val_size = int(val_split * ds_size)
    
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partition_tf(dataset)

# %%
len(train_ds)
# Out:
# 54

# %%
len(val_ds)
# Out:
# 6

# %%
len(test_ds)
# Out:
# 8

# %%
#Now for improving the performance of pipeline we use cache() tf function
#cache stores already loaded data on to ram if it is need again there by reducing the load times
#prefetch is usefull in loading next set of batch to cpu when gpu is still processing the work
#tf.data.AUTOTUNE will automatically decide how many batches to load on to cpu by tensorflow
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size = tf.data.AUTOTUNE)

#Now the data sets are optimized for training purposes

# %%
#Now we need to preprocessing.

#When ever we are working with images we need to scale the values to 0-1 basically images are rgb normally they are from 0-255.

#To sequential we will send our data.

#Why we are doing Resizing ==> while after training(prediciton stage) if we send any image of different size Resizing will 
#take care of it.

#To make our model robust we use augmentation techique.Why we need?==> if any image rotated or bad contrast augmentation will help.

resize_and_rescale = tf.keras.Sequential([
    layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.experimental.preprocessing.Rescaling(1.0/255)
])

# %%
#data augmentaion

data_augmentation = tf.keras.Sequential([
    layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    layers.experimental.preprocessing.RandomRotation(0.2),
])

# %%
#kernal size is size of the filter (3*3)
#filter = 1 for eye, 1 for nose, 1 for nose - image have head
#filter = 1 for legs, 1 for hands - image have body

#conv2D is convolutional layer
#after convolutional layer we have pooling

#Pooling =  we have different types of pooling 
#eg - max pooling = from matrix we take the max value

#Now by trail and error we must dedice how many convolutional and pooling layers we need and similar to 32 and 64s in conv2D

#Now we need to flatten the data

#Dense indicate connection with every output layers for single input layer
#softmax fucntion will normalize the propability of the classes

input_shape= (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNEL)
n_classes = 3

model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation='relu', input_shape = input_shape),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation='relu'),
    layers.MaxPooling2D((2,2)),
    
    layers.Flatten(),
    layers.Dense(64,activation='relu'),
    layers.Dense(n_classes, activation='softmax'),
])

model.build(input_shape=input_shape)
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (32, 256, 256, 3)         0
#
#  sequential_1 (Sequential)   (None, 256, 256, 3)       0
#
#  conv2d (Conv2D)             (None, 254, 254, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 32)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 64)        36928
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 64)        36928
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 64)       0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 12, 12, 64)        36928
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 3)                 195
#
# =================================================================
# Total params: 183,747
# Trainable params: 183,747
# Non-trainable params: 0
# _________________________________________________________________

# %%
#now compiling the model

model.compile(
    optimizer = 'adam',
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    epochs = EPOCHS,
    batch_size=BATCH_SIZE,
    verbose = 1,
    validation_data = val_ds
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# 54/54 [==============================] - 109s 2s/step - loss: 0.9067 - accuracy: 0.4855 - val_loss: 0.7973 - val_accuracy: 0.7188
# Epoch 2/100
# 54/54 [==============================] - 90s 2s/step - loss: 0.6170 - accuracy: 0.7367 - val_loss: 0.4205 - val_accuracy: 0.8490
# Epoch 3/100
# 54/54 [==============================] - 89s 2s/step - loss: 0.3631 - accuracy: 0.8652 - val_loss: 0.3656 - val_accuracy: 0.8698
# Epoch 4/100
# 54/54 [==============================] - 75s 1s/step - loss: 0.2863 - accuracy: 0.8819 - val_loss: 0.3022 - val_accuracy: 0.8490
# Epoch 5/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.2697 - accuracy: 0.8970 - val_loss: 0.2856 - val_accuracy: 0.8906
# Epoch 6/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.2347 - accuracy: 0.9097 - val_loss: 0.1225 - val_accuracy: 0.9583
# Epoch 7/100
# 54/54 [==============================] - 89s 2s/step - loss: 0.1497 - accuracy: 0.9433 - val_loss: 0.1436 - val_accuracy: 0.9479
# Epoch 8/100
# 54/54 [==============================] - 109s 2s/step - loss: 0.1112 - accuracy: 0.9583 - val_loss: 0.2155 - val_accuracy: 0.9219
# Epoch 9/100
# 54/54 [==============================] - 95s 2s/step - loss: 0.1702 - accuracy: 0.9387 - val_loss: 0.1523 - val_accuracy: 0.9323
# Epoch 10/100
# 54/54 [==============================] - 105s 2s/step - loss: 0.0961 - accuracy: 0.9682 - val_loss: 0.0618 - val_accuracy: 0.9792
# Epoch 11/100
# 54/54 [==============================] - 101s 2s/step - loss: 0.0739 - accuracy: 0.9716 - val_loss: 0.2143 - val_accuracy: 0.9271
# Epoch 12/100
# 54/54 [==============================] - 120s 2s/step - loss: 0.0749 - accuracy: 0.9740 - val_loss: 0.1804 - val_accuracy: 0.9375
# Epoch 13/100
# 54/54 [==============================] - 94s 2s/step - loss: 0.0896 - accuracy: 0.9693 - val_loss: 0.1211 - val_accuracy: 0.9323
# Epoch 14/100
# 54/54 [==============================] - 89s 2s/step - loss: 0.0927 - accuracy: 0.9635 - val_loss: 0.0845 - val_accuracy: 0.9740
# Epoch 15/100
# 54/54 [==============================] - 83s 2s/step - loss: 0.0521 - accuracy: 0.9838 - val_loss: 0.0516 - val_accuracy: 0.9844
# Epoch 16/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0481 - accuracy: 0.9855 - val_loss: 0.1090 - val_accuracy: 0.9688
# Epoch 17/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.1075 - accuracy: 0.9647 - val_loss: 0.1876 - val_accuracy: 0.9115
# Epoch 18/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0462 - accuracy: 0.9861 - val_loss: 0.0579 - val_accuracy: 0.9844
# Epoch 19/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0558 - accuracy: 0.9832 - val_loss: 0.1554 - val_accuracy: 0.9323
# Epoch 20/100
# 54/54 [==============================] - 74s 1s/step - loss: 0.0645 - accuracy: 0.9751 - val_loss: 0.0558 - val_accuracy: 0.9896
# Epoch 21/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0367 - accuracy: 0.9878 - val_loss: 0.0475 - val_accuracy: 0.9844
# Epoch 22/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0345 - accuracy: 0.9884 - val_loss: 0.1088 - val_accuracy: 0.9583
# Epoch 23/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0278 - accuracy: 0.9896 - val_loss: 0.1419 - val_accuracy: 0.9635
# Epoch 24/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.1255 - accuracy: 0.9595 - val_loss: 0.1999 - val_accuracy: 0.9323
# Epoch 25/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0387 - accuracy: 0.9844 - val_loss: 0.0338 - val_accuracy: 0.9896
# Epoch 26/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0283 - accuracy: 0.9925 - val_loss: 0.0916 - val_accuracy: 0.9740
# Epoch 27/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0382 - accuracy: 0.9867 - val_loss: 0.0781 - val_accuracy: 0.9688
# Epoch 28/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0311 - accuracy: 0.9873 - val_loss: 0.1091 - val_accuracy: 0.9740
# Epoch 29/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0497 - accuracy: 0.9786 - val_loss: 0.0632 - val_accuracy: 0.9792
# Epoch 30/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0325 - accuracy: 0.9878 - val_loss: 0.0325 - val_accuracy: 0.9896
# Epoch 31/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0295 - accuracy: 0.9919 - val_loss: 0.0319 - val_accuracy: 0.9896
# Epoch 32/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0181 - accuracy: 0.9936 - val_loss: 0.0323 - val_accuracy: 0.9844
# Epoch 33/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0520 - accuracy: 0.9821 - val_loss: 0.0468 - val_accuracy: 0.9792
# Epoch 34/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0494 - accuracy: 0.9838 - val_loss: 0.0468 - val_accuracy: 0.9792
# Epoch 35/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0592 - accuracy: 0.9769 - val_loss: 0.0818 - val_accuracy: 0.9792
# Epoch 36/100
# 54/54 [==============================] - 69s 1s/step - loss: 0.0244 - accuracy: 0.9907 - val_loss: 0.0752 - val_accuracy: 0.9844
# Epoch 37/100
# 54/54 [==============================] - 68s 1s/step - loss: 0.0240 - accuracy: 0.9913 - val_loss: 0.0331 - val_accuracy: 0.9844
# Epoch 38/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0218 - accuracy: 0.9913 - val_loss: 0.0388 - val_accuracy: 0.9792
# Epoch 39/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0178 - accuracy: 0.9931 - val_loss: 0.0573 - val_accuracy: 0.9844
# Epoch 40/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0215 - accuracy: 0.9948 - val_loss: 0.0293 - val_accuracy: 0.9844
# Epoch 41/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0280 - accuracy: 0.9884 - val_loss: 0.0580 - val_accuracy: 0.9688
# Epoch 42/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0936 - accuracy: 0.9647 - val_loss: 0.0988 - val_accuracy: 0.9635
# Epoch 43/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0478 - accuracy: 0.9850 - val_loss: 0.2705 - val_accuracy: 0.9062
# Epoch 44/100
# 54/54 [==============================] - 74s 1s/step - loss: 0.0327 - accuracy: 0.9919 - val_loss: 0.0213 - val_accuracy: 0.9896
# Epoch 45/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0277 - accuracy: 0.9890 - val_loss: 0.0239 - val_accuracy: 0.9948
# Epoch 46/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0312 - accuracy: 0.9925 - val_loss: 0.0521 - val_accuracy: 0.9896
# Epoch 47/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0317 - accuracy: 0.9896 - val_loss: 0.0156 - val_accuracy: 0.9948
# Epoch 48/100
# 54/54 [==============================] - 77s 1s/step - loss: 0.1423 - accuracy: 0.9525 - val_loss: 0.0929 - val_accuracy: 0.9583
# Epoch 49/100
# 54/54 [==============================] - 76s 1s/step - loss: 0.0192 - accuracy: 0.9919 - val_loss: 0.0573 - val_accuracy: 0.9844
# Epoch 50/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0091 - accuracy: 0.9965 - val_loss: 0.1088 - val_accuracy: 0.9531
# Epoch 51/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0148 - accuracy: 0.9959 - val_loss: 0.0526 - val_accuracy: 0.9792
# Epoch 52/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0244 - accuracy: 0.9925 - val_loss: 0.1234 - val_accuracy: 0.9531
# Epoch 53/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0466 - accuracy: 0.9850 - val_loss: 0.0479 - val_accuracy: 0.9844
# Epoch 54/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0114 - accuracy: 0.9977 - val_loss: 0.0216 - val_accuracy: 0.9948
# Epoch 55/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.0390 - val_accuracy: 0.9896
# Epoch 56/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0046 - accuracy: 0.9988 - val_loss: 0.0400 - val_accuracy: 0.9896
# Epoch 57/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0113 - accuracy: 0.9971 - val_loss: 0.0130 - val_accuracy: 1.0000
# Epoch 58/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 0.0481 - val_accuracy: 0.9896
# Epoch 59/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0767 - accuracy: 0.9763 - val_loss: 0.1328 - val_accuracy: 0.9375
# Epoch 60/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0603 - accuracy: 0.9809 - val_loss: 0.0478 - val_accuracy: 0.9896
# Epoch 61/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0180 - accuracy: 0.9931 - val_loss: 0.0464 - val_accuracy: 0.9844
# Epoch 62/100
# 54/54 [==============================] - 71s 1s/step - loss: 0.0254 - accuracy: 0.9919 - val_loss: 0.0340 - val_accuracy: 0.9896
# Epoch 63/100
# 54/54 [==============================] - 70s 1s/step - loss: 0.0087 - accuracy: 0.9965 - val_loss: 0.0155 - val_accuracy: 0.9948
# Epoch 64/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0206 - accuracy: 0.9925 - val_loss: 0.0238 - val_accuracy: 0.9844
# Epoch 65/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0127 - accuracy: 0.9931 - val_loss: 0.0120 - val_accuracy: 0.9948
# Epoch 66/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 0.0415 - val_accuracy: 0.9844
# Epoch 67/100
# 54/54 [==============================] - 72s 1s/step - loss: 0.0060 - accuracy: 0.9983 - val_loss: 0.0408 - val_accuracy: 0.9896
# Epoch 68/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0152 - accuracy: 0.9931 - val_loss: 0.0174 - val_accuracy: 0.9896
# Epoch 69/100
# 54/54 [==============================] - 13227s 250s/step - loss: 0.0603 - accuracy: 0.9821 - val_loss: 0.0989 - val_accuracy: 0.9688
# Epoch 70/100
# 54/54 [==============================] - 73s 1s/step - loss: 0.0314 - accuracy: 0.9896 - val_loss: 0.0725 - val_accuracy: 0.9792
# Epoch 71/100
# 54/54 [==============================] - 129s 2s/step - loss: 0.0353 - accuracy: 0.9855 - val_loss: 0.0701 - val_accuracy: 0.9688
# Epoch 72/100
# 54/54 [==============================] - 178s 3s/step - loss: 0.0133 - accuracy: 0.9954 - val_loss: 0.0333 - val_accuracy: 0.9844
# Epoch 73/100
# 54/54 [==============================] - 160s 3s/step - loss: 0.0122 - accuracy: 0.9994 - val_loss: 0.0220 - val_accuracy: 0.9896
# Epoch 74/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.0118 - accuracy: 0.9965 - val_loss: 0.0295 - val_accuracy: 0.9896
# Epoch 75/100
# 54/54 [==============================] - 131s 2s/step - loss: 0.0128 - accuracy: 0.9959 - val_loss: 0.0360 - val_accuracy: 0.9896
# Epoch 76/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.0072 - accuracy: 0.9977 - val_loss: 0.0108 - val_accuracy: 0.9948
# Epoch 77/100
# 54/54 [==============================] - 133s 2s/step - loss: 0.0096 - accuracy: 0.9977 - val_loss: 0.0052 - val_accuracy: 1.0000
# Epoch 78/100
# 54/54 [==============================] - 136s 3s/step - loss: 0.0143 - accuracy: 0.9959 - val_loss: 0.0605 - val_accuracy: 0.9688
# Epoch 79/100
# 54/54 [==============================] - 136s 3s/step - loss: 0.0109 - accuracy: 0.9942 - val_loss: 0.0291 - val_accuracy: 0.9948
# Epoch 80/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.0106 - accuracy: 0.9959 - val_loss: 0.0281 - val_accuracy: 0.9844
# Epoch 81/100
# 54/54 [==============================] - 142s 3s/step - loss: 0.0289 - accuracy: 0.9896 - val_loss: 0.0374 - val_accuracy: 0.9844
# Epoch 82/100
# 54/54 [==============================] - 140s 3s/step - loss: 0.0211 - accuracy: 0.9942 - val_loss: 0.0108 - val_accuracy: 0.9948
# Epoch 83/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.0046 - accuracy: 0.9994 - val_loss: 0.2865 - val_accuracy: 0.9271
# Epoch 84/100
# 54/54 [==============================] - 136s 3s/step - loss: 0.0409 - accuracy: 0.9890 - val_loss: 0.0074 - val_accuracy: 0.9948
# Epoch 85/100
# 54/54 [==============================] - 134s 2s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 9.4059e-04 - val_accuracy: 1.0000
# Epoch 86/100
# 54/54 [==============================] - 138s 3s/step - loss: 0.0031 - accuracy: 0.9983 - val_loss: 0.0082 - val_accuracy: 0.9948
# Epoch 87/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.0040 - accuracy: 0.9977 - val_loss: 0.0338 - val_accuracy: 0.9844
# Epoch 88/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.0027 - accuracy: 0.9983 - val_loss: 9.1530e-04 - val_accuracy: 1.0000
# Epoch 89/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0080 - val_accuracy: 0.9948
# Epoch 90/100
# 54/54 [==============================] - 135s 2s/step - loss: 0.0185 - accuracy: 0.9954 - val_loss: 0.0761 - val_accuracy: 0.9844
# Epoch 91/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.0847 - accuracy: 0.9763 - val_loss: 0.0663 - val_accuracy: 0.9792
# Epoch 92/100
# 54/54 [==============================] - 134s 2s/step - loss: 0.0575 - accuracy: 0.9815 - val_loss: 0.0314 - val_accuracy: 0.9896
# Epoch 93/100
# 54/54 [==============================] - 132s 2s/step - loss: 0.0058 - accuracy: 0.9977 - val_loss: 0.0036 - val_accuracy: 1.0000
# Epoch 94/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0176 - val_accuracy: 0.9948
# Epoch 95/100
# 54/54 [==============================] - 138s 3s/step - loss: 0.0048 - accuracy: 0.9988 - val_loss: 0.0039 - val_accuracy: 1.0000
# Epoch 96/100
# 54/54 [==============================] - 135s 3s/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0045 - val_accuracy: 1.0000
# Epoch 97/100
# 54/54 [==============================] - 140s 3s/step - loss: 3.7959e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 98/100
# 54/54 [==============================] - 140s 3s/step - loss: 7.3210e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 0.9948
# Epoch 99/100
# 54/54 [==============================] - 138s 3s/step - loss: 6.1798e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 0.9948
# Epoch 100/100
# 54/54 [==============================] - 139s 3s/step - loss: 0.0319 - accuracy: 0.9896 - val_loss: 0.0309 - val_accuracy: 0.9844

# %%
scores = model.evaluate(test_ds)
# Out:
# 8/8 [==============================] - 12s 682ms/step - loss: 0.0328 - accuracy: 0.9957

# %%
scores
# Out:
# [0.03284411504864693, 0.9956896305084229]

# %%
history

# %%
history.params
# Out:
# {'verbose': 1, 'epochs': 100, 'steps': 54}

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(range(EPOCHS), acc, label='Training Accuracy')
plt.plot(range(EPOCHS), val_acc, label='Validation Accuracy')
plt.legend(loc = 'lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1,2,2)
plt.plot(range(EPOCHS), loss, label='Training Loss')
plt.plot(range(EPOCHS), val_loss, label='Validation Loss')
plt.legend(loc = 'upper right')
plt.title('Training and Validation Loss')
# Out:
# Text(0.5, 1.0, 'Training and Validation Loss')

# %%
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype('uint8')
    first_label = labels_batch[0].numpy()
    
    print("first image to predict")
    plt.imshow(first_image)
    print("first image's actual label:", class_names[first_label])
    
    batch_prediction =  model.predict(images_batch)
    print("predicted label: " ,class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict
# first image's actual label: Potato___Early_blight
# 1/1 [==============================] - 2s 2s/step
# predicted label:  Potato___Early_blight

# %%
#Fuction - Taking model and image and telling what is the predicted class and confidence
def predict(model, img):
    img_array = tf.keras.preprocessing.image.img_to_array(images[i].numpy())
    img_array = tf.expand_dims(img_array, 0) #create a batch
    
    predictions = model.predict(img_array)
    
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = round(100 * (np.max(predictions[0])), 2)
    return predicted_class, confidence

# %%
plt.figure(figsize=(15,15))
for images, labels in test_ds.take(1):
    for i in range(9):
        ax = plt.subplot(3, 3, i+1)
        plt.imshow(images[i].numpy().astype("uint8"))
        
        predicted_class, confidence = predict(model, images[i].numpy())
        actual_class = class_names[labels[i]]
        
        plt.title(f"Actual: {actual_class}, \n Predicted: {predicted_class}, \n Confidence: {confidence}")
        
        plt.axis("off")
# Out:
# 1/1 [==============================] - 1s 539ms/step
# 1/1 [==============================] - 0s 112ms/step
# 1/1 [==============================] - 0s 95ms/step
# 1/1 [==============================] - 0s 97ms/step
# 1/1 [==============================] - 0s 98ms/step
# 1/1 [==============================] - 0s 122ms/step
# 1/1 [==============================] - 0s 111ms/step
# 1/1 [==============================] - 0s 104ms/step
# 1/1 [==============================] - 0s 126ms/step

# %%
import os
model_version = max([int(i) for i in os.listdir("../saved_models")]+[0])+1
model.save(f"../saved_models/{model_version}")
# Out:
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting ImageProjectiveTransformV3 cause there is no registered converter for this op.
# WARNING:absl:Found untraced functions such as _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op, _jit_compiled_convolution_op while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../saved_models/2\assets
# INFO:tensorflow:Assets written to: ../saved_models/2\assets
